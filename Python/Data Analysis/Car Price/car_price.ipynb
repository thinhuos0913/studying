# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load data
df = pd.read_csv('car.csv', delimiter='|',engine='python',error_bad_lines=False,warn_bad_lines=False, 
                 index_col=False, encoding='utf8')
df.head(10)
# Out:
#    car_model          km    imp_exp        km_1  imp_exp_1 car_type out_color  \
# 0  acura-mdx        0 Km  Nhập khẩu        0 Km  Nhập khẩu      SUV       Đen
# 1  acura-mdx        0 Km  Nhập khẩu        0 Km  Nhập khẩu      SUV       Bạc
# 2  acura-mdx        0 Km  Nhập khẩu        0 Km  Nhập khẩu      SUV       Bạc
# 3  acura-mdx        0 Km  Nhập khẩu        0 Km  Nhập khẩu      SUV       Đen
# 4  acura-mdx    9,600 Km  Nhập khẩu    9,600 Km  Nhập khẩu      SUV     Trắng
# 5  acura-mdx    9,700 Km  Nhập khẩu    9,700 Km  Nhập khẩu      SUV     Trắng
# 6  acura-mdx   86,000 Km  Nhập khẩu   86,000 Km  Nhập khẩu      SUV       Đen
# 7  acura-mdx        0 Km  Nhập khẩu        0 Km  Nhập khẩu      SUV      Xanh
# 8  acura-mdx   80,000 Km  Nhập khẩu   80,000 Km  Nhập khẩu      SUV       Đen
# 9  acura-mdx  150,000 Km  Nhập khẩu  150,000 Km  Nhập khẩu      SUV       Xám
#
#     in_color door_num seat_num new_old car_year                    title  \
# 0        Đen    5 cửa    7 chỗ   Xe cũ     2007  Acura MDX SH-AWD - 2007
# 1        Đen    5 cửa    7 chỗ   Xe cũ     2007  Acura MDX SH-AWD - 2007
# 2  Nhiều màu    5 cửa    7 chỗ   Xe cũ     2006  Acura MDX SH-AWD - 2006
# 3        Kem    5 cửa    7 chỗ  Xe mới     2016    Acura MDX 3.5L - 2016
# 4        Cát    5 cửa    7 chỗ   Xe cũ     2015    Acura MDX 3.5L - 2015
# 5        Kem    5 cửa    7 chỗ   Xe cũ     2015    Acura MDX 3.5L - 2015
# 6        Đen    5 cửa    7 chỗ   Xe cũ     2008  Acura MDX SH-AWD - 2008
# 7        Nâu    5 cửa    7 chỗ   Xe cũ     2004    Acura MDX 3.5L - 2004
# 8        Đen    5 cửa    7 chỗ   Xe cũ     2007  Acura MDX SH-AWD - 2007
# 9        Đen    5 cửa    7 chỗ   Xe cũ     2008  Acura MDX SH-AWD - 2008
#
#             price        area                      poster_name  \
# 0       630 Triệu      TP HCM    Liên hệ: Salon ô tô Thịnh Lợi
# 1       580 Triệu      Hà Nội            Liên hệ: Ngô Quốc Huy
# 2       465 Triệu      TP HCM    Liên hệ: Salon Auto Toàn Phát
# 3  4 Tỷ 665 Triệu      TP HCM           Liên hệ: Ôtô Ngọc Danh
# 4  3 Tỷ 400 Triệu      TP HCM  Liên hệ: Siêu Thị Ô Tô An Sương
# 5  3 Tỷ 450 Triệu      TP HCM  Liên hệ: Siêu Thị Ô Tô An Sương
# 6       620 Triệu  Bình Dương         Liên hệ: Phạm Trung Dũng
# 7       290 Triệu   Hải Dương                    Liên hệ: dung
# 8       555 Triệu      Hà Nội         Liên hệ: Auto Car Center
# 9       639 Triệu      Hà Nội           Liên hệ: Dao van Thinh
#
#                                           poster_add  \
# 0  Số 56+58+60 (C3/1 cũ) Phạm Hùng, Bình Chánh TP...
# 1                           Nguyễn khánh toán Hà Nội
# 2      C1/25 Phạm Hùng Chánh Hưng, Bình Chánh TP HCM
# 3                     C3/02 Phạm Hùng, Quận 8 TP HCM
# 4            Nguyễn Ảnh Thủ, Bà Điểm, Hóc Môn TP HCM
# 5            Nguyễn Ảnh Thủ, Bà Điểm, Hóc Môn TP HCM
# 6          Bình chuẩn Thuận An Bình Dương Bình Dương
# 7                                hai duong Hải Dương
# 8              Số 9 Nguyễn Văn Cừ - Long Biên Hà Nội
# 9                     Ngõ 100 hoàng quốc việt Hà Nội
#
#                         poster_tel
# 0  ĐT: 0961 258 258 - 0943 331 999
# 1                 ĐT: 0903 245 739
# 2  ĐT: 0903 951 109 - 0938 595 373
# 3                 ĐT: 0919 726 666
# 4  ĐT: 0789 455 699 - 0993 777 977
# 5  ĐT: 0789 455 699 - 0993 777 977
# 6  ĐT: 0826 858 585 - 0362 727 272
# 7                 ĐT: 0984 396 928
# 8                 ĐT: 0976 860 594
# 9                 ĐT: 0903 210 090

# %%
# Report theo kiểu xe
df_car_type = df.groupby('car_type').count()
df_car_type.sort_values(by='car_model',inplace=True)
df_car_type[-7:]
# Out:
#                     car_model     km  imp_exp   km_1  imp_exp_1  out_color  \
# car_type
# Truck                    1672   1672     1672   1672       1672       1672
# Bán tải / Pickup       2328   2328     2328   2328       2328       2328
# Van/Minivan              2409   2409     2409   2409       2409       2409
# Crossover                3011   3011     3011   3011       3011       3011
# Hatchback                5383   5383     5383   5383       5383       5383
# SUV                     10692  10692    10692  10692      10692      10692
# Sedan                   13615  13615    13615  13615      13615      13615
#
#                     in_color  door_num  seat_num  new_old  car_year  title  \
# car_type
# Truck                   1672      1672      1672     1672      1672   1672
# Bán tải / Pickup      2328      2328      2328     2328      2328   2328
# Van/Minivan             2409      2409      2409     2409      2409   2409
# Crossover               3011      3011      3011     3011      3011   3011
# Hatchback               5383      5383      5383     5383      5383   5383
# SUV                    10692     10692     10692    10692     10692  10692
# Sedan                  13615     13615     13615    13615     13615  13615
#
#                     price   area  poster_name  poster_add  poster_tel
# car_type
# Truck                1672   1672         1672        1672        1672
# Bán tải / Pickup   2328   2328         2328        2328        2328
# Van/Minivan          2409   2409         2409        2409        2409
# Crossover            3011   3011         3011        3011        3011
# Hatchback            5383   5383         5383        5383        5383
# SUV                 10692  10692        10692       10692       10692
# Sedan               13615  13615        13615       13615       13615

# %%
# Vẽ theo kiểu xe
ax = df_car_type[-7:].plot.pie(y='car_model',legend=3,figsize=(20, 10), title='Tỷ lệ các loại xe',autopct='%.2f')
ax.set_ylabel('')
# plt.show()
# Out:
# Text(0, 0.5, '')

# %%
# Tổng hợp theo hãng xe
df_car_brand = df.copy()
df_car_brand['tmp'] = df_car_brand['car_model'].str.find('-')

df_car_brand['car_brand'] = df_car_brand.apply(lambda x: x['car_model'][:x['tmp']] if x['tmp']!= -1 else 'others', 1) 
df_car_brand['car_brand'].unique()
# Out:
# array(['acura', 'audi', 'bmw', 'chevrolet', 'daewoo', 'daihatsu', 'fiat',
#        'ford', 'honda', 'hyundai', 'isuzu', 'kia', 'landrover', 'lexus',
#        'mazda', 'mercedes_benz', 'mitsubishi', 'nissan', 'peugeot',
#        'porsche', 'renault', 'suzuki', 'toyota', 'vinfast', 'volkswagen',
#        'others', 'alfa_romeo', 'asia', 'baic', 'bentley', 'brilliance',
#        'byd', 'cadillac', 'changan', 'chery', 'chrysler', 'dodge',
#        'dongfeng', 'ferrari', 'gaz', 'geely', 'haima', 'hino', 'hummer',
#        'infiniti', 'jaguar', 'jeep', 'jrd', 'lada', 'lamborghini',
#        'lifan', 'lincoln', 'luxgen', 'maserati', 'mekong', 'mg', 'mini',
#        'opel', 'proton', 'ram', 'rolls_royce', 'samsung', 'smart',
#        'ssangyong', 'subaru', 'sym', 'tesla', 'thaco', 'tobe', 'uaz',
#        'vinaxuki', 'volvo', 'zotye'], dtype=object)

# %%
# Vẽ theo loại xe
df_draw = df_car_brand[['car_model','car_brand']].groupby('car_brand').count()
df_draw.sort_values(by='car_model',inplace=True)
ax = df_draw[-8:].plot.pie(y='car_model',legend=3,figsize=(30, 10), title='Tỷ lệ các hãng xe',autopct='%.2f')
ax.set_ylabel('')
plt.show()

# %%
# Vẽ theo màu xe out_color
df_color = df.groupby('out_color').count() # Group by ngoại thất color

df_color.sort_values(by='car_model',inplace=True)

ax = df_color[-10:].plot.pie(y='car_model',legend=3,figsize=(20, 10), title='Tỷ lệ màu sắc',autopct='%.2f')
ax.set_ylabel('')
plt.show()

# %%
# Xét theo số km xe cũ?
df_old_car = df[df['new_old']=='Xe cũ']
#Xoá Km
df_old_car['km_number'] = df_old_car['km'].str.replace(' Km','')
# Xoá ','
df_old_car['km_number'] = df_old_car['km_number'].str.replace(',','')
# Chuyển về kiểu số
df_old_car['km_number'] = df_old_car['km_number'].astype(float)
# Out:
# <ipython-input-9-e61d1ec87861>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_old_car['km_number'] = df_old_car['km'].str.replace(' Km','')
# <ipython-input-9-e61d1ec87861>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_old_car['km_number'] = df_old_car['km_number'].str.replace(',','')
# <ipython-input-9-e61d1ec87861>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_old_car['km_number'] = df_old_car['km_number'].astype(float)

# %%
# Bỏ đi các dữ liệu lỗi
df_old_car = df_old_car[df_old_car['km_number']!=0]
df_old_car
# Out:
#        car_model          km             imp_exp        km_1  \
# 4      acura-mdx    9,600 Km           Nhập khẩu    9,600 Km
# 5      acura-mdx    9,700 Km           Nhập khẩu    9,700 Km
# 6      acura-mdx   86,000 Km           Nhập khẩu   86,000 Km
# 8      acura-mdx   80,000 Km           Nhập khẩu   80,000 Km
# 9      acura-mdx  150,000 Km           Nhập khẩu  150,000 Km
# ...          ...         ...                 ...         ...
# 39374  hang_khac   57,000 Km  Lắp ráp trong nước   57,000 Km
# 39380  hang_khac  150,000 Km  Lắp ráp trong nước  150,000 Km
# 39406  hang_khac   13,000 Km  Lắp ráp trong nước   13,000 Km
# 39408  hang_khac  100,000 Km  Lắp ráp trong nước  100,000 Km
# 39419  hang_khac   25,000 Km  Lắp ráp trong nước   25,000 Km
#
#                 imp_exp_1     car_type out_color   in_color door_num seat_num  \
# 4               Nhập khẩu          SUV     Trắng        Cát    5 cửa    7 chỗ
# 5               Nhập khẩu          SUV     Trắng        Kem    5 cửa    7 chỗ
# 6               Nhập khẩu          SUV       Đen        Đen    5 cửa    7 chỗ
# 8               Nhập khẩu          SUV       Đen        Đen    5 cửa    7 chỗ
# 9               Nhập khẩu          SUV       Xám        Đen    5 cửa    7 chỗ
# ...                   ...          ...       ...        ...      ...      ...
# 39374  Lắp ráp trong nước        Truck      Xanh  Nhiều màu    2 cửa    3 chỗ
# 39380  Lắp ráp trong nước        Truck      Xanh       Xanh    2 cửa    3 chỗ
# 39406  Lắp ráp trong nước        Truck      Xanh   Màu khác    2 cửa    3 chỗ
# 39408  Lắp ráp trong nước        Truck      Xanh        Đen    2 cửa    2 chỗ
# 39419  Lắp ráp trong nước  Van/Minivan       Đen       Xanh    1 cửa   29 chỗ
#
#       new_old car_year                    title           price        area  \
# 4       Xe cũ     2015    Acura MDX 3.5L - 2015  3 Tỷ 400 Triệu      TP HCM
# 5       Xe cũ     2015    Acura MDX 3.5L - 2015  3 Tỷ 450 Triệu      TP HCM
# 6       Xe cũ     2008  Acura MDX SH-AWD - 2008       620 Triệu  Bình Dương
# 8       Xe cũ     2007  Acura MDX SH-AWD - 2007       555 Triệu      Hà Nội
# 9       Xe cũ     2008  Acura MDX SH-AWD - 2008       639 Triệu      Hà Nội
# ...       ...      ...                      ...             ...         ...
# 39374   Xe cũ     2015          TMT 7t65 - 2015       285 Triệu     Hà Tĩnh
# 39380   Xe cũ     2007        Giải phóng - 2007        45 Triệu   Thanh Hóa
# 39406   Xe cũ     2018              VEAM - 2018       200 Triệu    Tây Ninh
# 39408   Xe cũ     2010        Veam 1,75T - 2010       120 Triệu      TP HCM
# 39419   Xe cũ     2017              FUSO - 2017  1 Tỷ 150 Triệu      Hà Nội
#
#                            poster_name  \
# 4      Liên hệ: Siêu Thị Ô Tô An Sương
# 5      Liên hệ: Siêu Thị Ô Tô An Sương
# 6             Liên hệ: Phạm Trung Dũng
# 8             Liên hệ: Auto Car Center
# 9               Liên hệ: Dao van Thinh
# ...                                ...
# 39374             Liên hệ: Trương Ngân
# 39380         Liên hệ: Trần minh Khang
# 39406          Liên hệ: Huynh Thanh Tu
# 39408         Liên hệ: Nguyễn Duy Hùng
# 39419             Liên hệ: Buitrunghau
#
#                                            poster_add  \
# 4             Nguyễn Ảnh Thủ, Bà Điểm, Hóc Môn TP HCM
# 5             Nguyễn Ảnh Thủ, Bà Điểm, Hóc Môn TP HCM
# 6           Bình chuẩn Thuận An Bình Dương Bình Dương
# 8               Số 9 Nguyễn Văn Cừ - Long Biên Hà Nội
# 9                      Ngõ 100 hoàng quốc việt Hà Nội
# ...                                               ...
# 39374                               Cẩm Xuyên Hà Tĩnh
# 39380    lê lai - thị trấn ngọc lặc - thanh Thanh Hóa
# 39406                            Tp tay ninh Tây Ninh
# 39408                  Chợ Đêm Làng Đh Thủ Đức TP HCM
# 39419  Phường hợp giang, tp cao bằng, cao bằng Hà Nội
#
#                             poster_tel  km_number
# 4      ĐT: 0789 455 699 - 0993 777 977     9600.0
# 5      ĐT: 0789 455 699 - 0993 777 977     9700.0
# 6      ĐT: 0826 858 585 - 0362 727 272    86000.0
# 8                     ĐT: 0976 860 594    80000.0
# 9                     ĐT: 0903 210 090   150000.0
# ...                                ...        ...
# 39374                 ĐT: 0824 601 809    57000.0
# 39380                 ĐT: 0919 523 565   150000.0
# 39406                 ĐT: 0974 282 285    13000.0
# 39408                 ĐT: 0919 343 879   100000.0
# 39419                 ĐT: 0916 949 883    25000.0
#
# [19607 rows x 19 columns]

# %%
# Remove các dữ liệu trên 1 Million km
df_old_car = df_old_car [df_old_car['km_number']<1000000]

# %%
# Plot histoframn
ax = df_old_car[df_old_car['km_number']<=100000].hist(figsize=(20, 10),color='#86bf91', rwidth=0.9)
plt.title('Số lượng xe bán theo khoảng công tơ mét')
plt.show()

# %%
# Xử lý giá (price)
df_price = df.copy()
df_price_B = df_price[df_price['price'].str.contains('Tỷ')]
df_price_M = df_price[~df_price['price'].str.contains('Tỷ')]

df_price_M['tmp'] = df_price_M['price'].str.replace(' Triệu','')
df_price_M['price_number'] = df_price_M['tmp'].astype(float)

df_price_M.drop (columns=['tmp'],inplace=True)


df_price_B['tmp'] =  df_price_B['price'].str.replace(' Triệu','')
df_price_B['tmp_idx'] =  df_price_B['price'].str.find(' Tỷ')
df_price_B['price_number_b'] = df_price_B.apply(lambda x: x['tmp'][:x['tmp_idx']], 1)
df_price_B['price_number_m'] = df_price_B.apply(lambda x: x['tmp'][x['tmp_idx']+3:] if len(x['tmp'])>x['tmp_idx']+3 else 0, 1)
df_price_B['price_number_b'] = df_price_B['price_number_b'].astype(float)
df_price_B['price_number_m'] = df_price_B['price_number_m'].astype(float)

df_price_B['price_number'] = df_price_B['price_number_b']*1000 + df_price_B['price_number_m']
# print(df_price_B.tail(10))
df_price_B.drop (columns=['price_number_b','price_number_m','tmp','tmp_idx'],inplace=True)

df_price_final = pd.concat([df_price_M, df_price_B])
# print(df_price_final.tail(10))
# df_price_final['price_number'].hist(figsize=(20, 10),color='b', bins=25)
df_price_final[df_price_final['price_number']<2500].hist(figsize=(30, 10),color='r', bins=25)
plt.show()
# Out:
# <ipython-input-13-69f4d2171d44>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_price_M['tmp'] = df_price_M['price'].str.replace(' Triệu','')
# <ipython-input-13-69f4d2171d44>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_price_M['price_number'] = df_price_M['tmp'].astype(float)
# C:\Users\tanth_000\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <ipython-input-13-69f4d2171d44>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_price_B['tmp'] =  df_price_B['price'].str.replace(' Triệu','')
# <ipython-input-13-69f4d2171d44>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_price_B['tmp_idx'] =  df_price_B['price'].str.find(' Tỷ')
# <ipython-input-13-69f4d2171d44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_price_B['price_number_b'] = df_price_B.apply(lambda x: x['tmp'][:x['tmp_idx']], 1)
# <ipython-input-13-69f4d2171d44>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_price_B['price_number_m'] = df_price_B.apply(lambda x: x['tmp'][x['tmp_idx']+3:] if len(x['tmp'])>x['tmp_idx']+3 else 0, 1)
# <ipython-input-13-69f4d2171d44>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_price_B['price_number_b'] = df_price_B['price_number_b'].astype(float)
# <ipython-input-13-69f4d2171d44>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_price_B['price_number_m'] = df_price_B['price_number_m'].astype(float)
# <ipython-input-13-69f4d2171d44>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_price_B['price_number'] = df_price_B['price_number_b']*1000 + df_price_B['price_number_m']
